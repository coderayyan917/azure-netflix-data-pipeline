# %%
dbutils.widgets.text("weekday", "7")  # dummy date default, just for manual testing

# %%
var = int(dbutils.widgets.get("weekday"))


# from datetime import datetime

# date_str = dbutils.widgets.get("weekday")
# var = datetime.strptime(date_str, "%Y-%m-%d").isoweekday()  # Monday=1 ... Sunday=7

# %%
dbutils.jobs.taskValues.set(key="weekoutput", value=var)

# %%
var = dbutils.jobs.taskValues.get(taskKey="WeekDayLookup", key="weekoutput")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <command-8394594542396637>, line 1
# ----> 1 var = dbutils.jobs.taskValues.get(taskKey="WeekDayLookup", key="weekoutput")
#
# File /databricks/python_shell/lib/dbruntime/dbutils.py:288, in DBUtils.JobsHandler.TaskValuesHandler.get(self, taskKey, key, default, debugValue)
#     286 elif is_not_in_job_context:
#     287     if debugValue is None:
# --> 288         raise patch_exception_with_error_details(
#     289             TypeError(
#     290                 'Must pass debugValue when calling get outside of a job context. debugValue cannot be None.'
#     291             ),
#     292             DriverErrorCode.
#     293             DBUTILS_DEBUG_VALUE_MISSING_OUTSIDE_JOB_CONTEXT  # type: ignore[attr-defined]
#     294         ) from None
#     295     return debugValue
#     297 raise
#
# ...

# %%
print(var)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-8394594542396656>, line 1
# ----> 1 print(var)
#
# NameError: name 'var' is not defined
